# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

mat = scipy.io.loadmat(r'C:\Users\sound\Desktop\data\brgm\data\Données\morpho\Profils TV + bisca\TRUCVERT\TrucVert_OCA.mat')
date=mat['date']
D=date[0,:]
x=mat['x']
x=x[0,:]
z=mat['z']

newz=np.delete(z,range(1400,3500),1)
newx=np.delete(x,range(1400,3500))


Z=np.ones(len(newx))

for x in range(0,len(Z)):
    Z[x]=newz[:,x].mean()
    
for i in range(1,168):
    plt.plot(newx,newz[i,:],'lightgray')
    
plt.plot(newx,Z,'k--',linewidth=3)
plt.show()
